# %% [markdown]
# # Model Selection, Underfitting, and Overfitting
# :label:`sec_model_selection`
#
# As machine learning scientists,
# our goal is to discover *patterns*.
# But how can we be sure that we have
# truly discovered a *general* pattern
# and not simply memorized our data?
# For example, imagine that we wanted to hunt
# for patterns among genetic markers
# linking patients to their dementia status,
# where the labels are drawn from the set
# $\{\text{dementia}, \text{mild cognitive impairment}, \text{healthy}\}$.
# Because each person's genes identify them uniquely
# (ignoring identical siblings),
# it is possible to memorize the entire dataset.
#
# We do not want our model to say
# *"That's Bob! I remember him! He has dementia!"*
# The reason why is simple.
# When we deploy the model in the future,
# we will encounter patients
# that the model has never seen before.
# Our predictions will only be useful
# if our model has truly discovered a *general* pattern.
#
# To recapitulate more formally,
# our goal is to discover patterns
# that capture regularities in the underlying population
# from which our training set was drawn.
# If we are successful in this endeavor,
# then we could successfully assess risk
# even for individuals that we have never encountered before.
# This problem---how to discover patterns that *generalize*---is
# the fundamental problem of machine learning.
#
# The danger is that when we train models,
# we access just a small sample of data.
# The largest public image datasets contain
# roughly one million images.
# More often, we must learn from only thousands
# or tens of thousands of data examples.
# In a large hospital system, we might access
# hundreds of thousands of medical records.
# When working with finite samples, we run the risk
# that we might discover apparent associations
# that turn out not to hold up when we collect more data.
#
# The phenomenon of fitting our training data
# more closely than we fit the underlying distribution is called *overfitting*, and the techniques used to combat overfitting are called *regularization*.
# In the previous sections, you might have observed
# this effect while experimenting with the Fashion-MNIST dataset.
# If you altered the model structure or the hyperparameters during the experiment, you might have noticed that with enough neurons, layers, and training epochs, the model can eventually reach perfect accuracy on the training set, even as the accuracy on test data deteriorates.
#
#
# ## Training Error and Generalization Error
#
# In order to discuss this phenomenon more formally,
# we need to differentiate between training error and generalization error.
# The *training error* is the error of our model
# as calculated on the training dataset,
# while *generalization error* is the expectation of our model's error
# were we to apply it to an infinite stream of additional data examples
# drawn from the same underlying data distribution as our original sample.
#
# Problematically, we can never calculate the generalization error exactly.
# That is because the stream of infinite data is an imaginary object.
# In practice, we must *estimate* the generalization error
# by applying our model to an independent test set
# constituted of a random selection of data examples
# that were withheld from our training set.
#
# The following three thought experiments
# will help illustrate this situation better.
# Consider a college student trying to prepare for his final exam.
# A diligent student will strive to practice well
# and test his abilities using exams from previous years.
# Nonetheless, doing well on past exams is no guarantee
# that he will excel when it matters.
# For instance, the student might try to prepare
# by rote learning the answers to the exam questions.
# This requires the student to memorize many things.
# She might even remember the answers for past exams perfectly.
# Another student might prepare by trying to understand
# the reasons for giving certain answers.
# In most cases, the latter student will do much better.
#
# Likewise, consider a model that simply uses a lookup table to answer questions. If the set of allowable inputs is discrete and reasonably small, then perhaps after viewing *many* training examples, this approach would perform well. Still this model has no ability to do better than random guessing when faced with examples that it has never seen before.
# In reality the input spaces are far too large to memorize the answers corresponding to every conceivable input. For example, consider the black and white $28\times28$ images. If each pixel can take one among $256$ grayscale values, then there are $256^{784}$ possible images. That means that there are far more low-resolution grayscale thumbnail-sized images than there are atoms in the universe. Even if we could encounter such data, we could never afford to store the lookup table.
#
# Last, consider the problem of trying
# to classify the outcomes of coin tosses (class 0: heads, class 1: tails)
# based on some contextual features that might be available.
# Suppose that the coin is fair.
# No matter what algorithm we come up with,
# the generalization error will always be $\frac{1}{2}$.
# However, for most algorithms,
# we should expect our training error to be considerably lower,
# depending on the luck of the draw,
# even if we did not have any features!
# Consider the dataset {0, 1, 1, 1, 0, 1}.
# Our feature-less algorithm would have to fall back on always predicting
# the *majority class*, which appears from our limited sample to be *1*.
# In this case, the model that always predicts class 1
# will incur an error of $\frac{1}{3}$,
# considerably better than our generalization error.
# As we increase the amount of data,
# the probability that the fraction of heads
# will deviate significantly from $\frac{1}{2}$ diminishes,
# and our training error would come to match the generalization error.
#
# ### Statistical Learning Theory
#
# Since generalization is the fundamental problem in machine learning,
# you might not be surprised to learn
# that many mathematicians and theorists have dedicated their lives
# to developing formal theories to describe this phenomenon.
# In their [eponymous theorem](https://en.wikipedia.org/wiki/Glivenko%E2%80%93Cantelli_theorem), Glivenko and Cantelli
# derived the rate at which the training error
# converges to the generalization error.
# In a series of seminal papers, [Vapnik and Chervonenkis](https://en.wikipedia.org/wiki/Vapnik%E2%80%93Chervonenkis_theory)
# extended this theory to more general classes of functions.
# This work laid the foundations of statistical learning theory.
#
#
# In the standard supervised learning setting, which we have addressed up until now and will stick with throughout most of this book,
# we assume that both the training data and the test data
# are drawn *independently* from *identical* distributions.
# This is commonly called the *i.i.d. assumption*,
# which means that the process that samples our data has no memory.
# In other words,
# the second example drawn and the third drawn
# are no more correlated than the second and the two-millionth sample drawn.
#
# Being a good machine learning scientist requires thinking critically,
# and already you should be poking holes in this assumption,
# coming up with common cases where the assumption fails.
# What if we train a mortality risk predictor
# on data collected from patients at UCSF Medical Center,
# and apply it on patients at Massachusetts General Hospital?
# These distributions are simply not identical.
# Moreover, draws might be correlated in time.
# What if we are classifying the topics of Tweets?
# The news cycle would create temporal dependencies
# in the topics being discussed, violating any assumptions of independence.
#
# Sometimes we can get away with minor violations of the i.i.d. assumption
# and our models will continue to work remarkably well.
# After all, nearly every real-world application
# involves at least some minor violation of the i.i.d. assumption,
# and yet we have many useful tools for
# various applications such as
# face recognition,
# speech recognition, and language translation.
#
# Other violations are sure to cause trouble.
# Imagine, for example, if we try to train
# a face recognition system by training it
# exclusively on university students
# and then want to deploy it as a tool
# for monitoring geriatrics in a nursing home population.
# This is unlikely to work well since college students
# tend to look considerably different from the elderly.
#
# In subsequent chapters, we will discuss problems
# arising from violations of the i.i.d. assumption.
# For now, even taking the i.i.d. assumption for granted,
# understanding generalization is a formidable problem.
# Moreover, elucidating the precise theoretical foundations
# that might explain why deep neural networks generalize as well as they do
# continues to vex the greatest minds in learning theory.
#
# When we train our models, we attempt to search for a function
# that fits the training data as well as possible.
# If the function is so flexible that it can catch on to spurious patterns
# just as easily as to true associations,
# then it might perform *too well* without producing a model
# that generalizes well to unseen data.
# This is precisely what we want to avoid or at least control.
# Many of the techniques in deep learning are heuristics and tricks
# aimed at guarding against overfitting.
#
# ### Model Complexity
#
# When we have simple models and abundant data,
# we expect the generalization error to resemble the training error.
# When we work with more complex models and fewer examples,
# we expect the training error to go down but the generalization gap to grow.
# What precisely constitutes model complexity is a complex matter.
# Many factors govern whether a model will generalize well.
# For example a model with more parameters might be considered more complex.
# A model whose parameters can take a wider range of values
# might be more complex.
# Often with neural networks, we think of a model
# that takes more training iterations as more complex,
# and one subject to *early stopping* (fewer training iterations) as less complex.
#
# It can be difficult to compare the complexity among members
# of substantially different model classes
# (say, decision trees vs. neural networks).
# For now, a simple rule of thumb is quite useful:
# a model that can readily explain arbitrary facts
# is what statisticians view as complex,
# whereas one that has only a limited expressive power
# but still manages to explain the data well
# is probably closer to the truth.
# In philosophy, this is closely related to Popper's
# criterion of falsifiability
# of a scientific theory: a theory is good if it fits data
# and if there are specific tests that can be used to disprove it.
# This is important since all statistical estimation is
# *post hoc*,
# i.e., we estimate after we observe the facts,
# hence vulnerable to the associated fallacy.
# For now, we will put the philosophy aside and stick to more tangible issues.
#
# In this section, to give you some intuition,
# we will focus on a few factors that tend
# to influence the generalizability of a model class:
#
# 1. The number of tunable parameters. When the number of tunable parameters, sometimes called the *degrees of freedom*, is large, models tend to be more susceptible to overfitting.
# 1. The values taken by the parameters. When weights can take a wider range of values, models can be more susceptible to overfitting.
# 1. The number of training examples. It is trivially easy to overfit a dataset containing only one or two examples even if your model is simple. But overfitting a dataset with millions of examples requires an extremely flexible model.
#
# ## Model Selection
#
# In machine learning, we usually select our final model
# after evaluating several candidate models.
# This process is called *model selection*.
# Sometimes the models subject to comparison
# are fundamentally different in nature
# (say, decision trees vs. linear models).
# At other times, we are comparing
# members of the same class of models
# that have been trained with different hyperparameter settings.
#
# With MLPs, for example,
# we may wish to compare models with
# different numbers of hidden layers,
# different numbers of hidden units,
# and various choices of the activation functions
# applied to each hidden layer.
# In order to determine the best among our candidate models,
# we will typically employ a validation dataset.
#
#
# ### Validation Dataset
#
# In principle we should not touch our test set
# until after we have chosen all our hyperparameters.
# Were we to use the test data in the model selection process,
# there is a risk that we might overfit the test data.
# Then we would be in serious trouble.
# If we overfit our training data,
# there is always the evaluation on test data to keep us honest.
# But if we overfit the test data, how would we ever know?
#
#
# Thus, we should never rely on the test data for model selection.
# And yet we cannot rely solely on the training data
# for model selection either because
# we cannot estimate the generalization error
# on the very data that we use to train the model.
#
#
# In practical applications, the picture gets muddier.
# While ideally we would only touch the test data once,
# to assess the very best model or to compare
# a small number of models to each other,
# real-world test data is seldom discarded after just one use.
# We can seldom afford a new test set for each round of experiments.
#
# The common practice to address this problem
# is to split our data three ways,
# incorporating a *validation dataset* (or *validation set*)
# in addition to the training and test datasets.
# The result is a murky practice where the boundaries
# between validation and test data are worryingly ambiguous.
# Unless explicitly stated otherwise, in the experiments in this book
# we are really working with what should rightly be called
# training data and validation data, with no true test sets.
# Therefore, the accuracy reported in each experiment of the book is really the validation accuracy and not a true test set accuracy.
#
# ### $K$-Fold Cross-Validation
#
# When training data is scarce,
# we might not even be able to afford to hold out
# enough data to constitute a proper validation set.
# One popular solution to this problem is to employ
# $K$*-fold cross-validation*.
# Here, the original training data is split into $K$ non-overlapping subsets.
# Then model training and validation are executed $K$ times,
# each time training on $K-1$ subsets and validating
# on a different subset (the one not used for training in that round).
# Finally, the training and validation errors are estimated
# by averaging over the results from the $K$ experiments.
#
# ## Underfitting or Overfitting?
#
# When we compare the training and validation errors,
# we want to be mindful of two common situations.
# First, we want to watch out for cases
# when our training error and validation error are both substantial
# but there is a little gap between them.
# If the model is unable to reduce the training error,
# that could mean that our model is too simple
# (i.e., insufficiently expressive)
# to capture the pattern that we are trying to model.
# Moreover, since the *generalization gap*
# between our training and validation errors is small,
# we have reason to believe that we could get away with a more complex model.
# This phenomenon is known as *underfitting*.
#
# On the other hand, as we discussed above,
# we want to watch out for the cases
# when our training error is significantly lower
# than our validation error, indicating severe *overfitting*.
# Note that overfitting is not always a bad thing.
# With deep learning especially, it is well known
# that the best predictive models often perform
# far better on training data than on holdout data.
# Ultimately, we usually care more about the validation error
# than about the gap between the training and validation errors.
#
# Whether we overfit or underfit can depend
# both on the complexity of our model
# and the size of the available training datasets,
# two topics that we discuss below.
#
# ### Model Complexity
#
# To illustrate some classical intuition
# about overfitting and model complexity,
# we give an example using polynomials.
# Given training data consisting of a single feature $x$
# and a corresponding real-valued label $y$,
# we try to find the polynomial of degree $d$
#
# $$\hat{y}= \sum_{i=0}^d x^i w_i$$
#
# to estimate the labels $y$.
# This is just a linear regression problem
# where our features are given by the powers of $x$,
# the model's weights are given by $w_i$,
# and the bias is given by $w_0$ since $x^0 = 1$ for all $x$.
# Since this is just a linear regression problem,
# we can use the squared error as our loss function.
#
#
# A higher-order polynomial function is more complex
# than a lower-order polynomial function,
# since the higher-order polynomial has more parameters
# and the model function's selection range is wider.
# Fixing the training dataset,
# higher-order polynomial functions should always
# achieve lower (at worst, equal) training error
# relative to lower degree polynomials.
# In fact, whenever the data examples each have a distinct value of $x$,
# a polynomial function with degree equal to the number of data examples
# can fit the training set perfectly.
# We visualize the relationship between polynomial degree
# and underfitting vs. overfitting in :numref:`fig_capacity_vs_error`.
#
# ![Influence of model complexity on underfitting and overfitting](../img/capacity-vs-error.svg)
# :label:`fig_capacity_vs_error`
#
# ### Dataset Size
#
# The other big consideration to bear in mind is the dataset size.
# Fixing our model, the fewer samples we have in the training dataset,
# the more likely (and more severely) we are to encounter overfitting.
# As we increase the amount of training data,
# the generalization error typically decreases.
# Moreover, in general, more data never hurt.
# For a fixed task and data distribution,
# there is typically a relationship between model complexity and dataset size.
# Given more data, we might profitably attempt to fit a more complex model.
# Absent sufficient data, simpler models may be more difficult to beat.
# For many tasks, deep learning only outperforms linear models
# when many thousands of training examples are available.
# In part, the current success of deep learning
# owes to the current abundance of massive datasets
# due to Internet companies, cheap storage, connected devices,
# and the broad digitization of the economy.
#
# ## Polynomial Regression
#
# We can now (**explore these concepts interactively
# by fitting polynomials to data.**)

# %%
import math
import numpy as np
import torch
from torch import nn
from d2l import torch as d2l

# %% [markdown]
# ### Generating the Dataset
#
# First we need data. Given $x$, we will [**use the following cubic polynomial to generate the labels**] on training and test data:
#
# (**$$y = 5 + 1.2x - 3.4\frac{x^2}{2!} + 5.6 \frac{x^3}{3!} + \epsilon \text{ where }
# \epsilon \sim \mathcal{N}(0, 0.1^2).$$**)
#
# The noise term $\epsilon$ obeys a normal distribution
# with a mean of 0 and a standard deviation of 0.1.
# For optimization, we typically want to avoid
# very large values of gradients or losses.
# This is why the *features*
# are rescaled from $x^i$ to $\frac{x^i}{i!}$.
# It allows us to avoid very large values for large exponents $i$.
# We will synthesize 100 samples each for the training set and test set.

# %%
max_degree = 20  # Maximum degree of the polynomial
n_train, n_test = 100, 100  # Training and test dataset sizes
true_w = np.zeros(max_degree)  # Allocate lots of empty space
true_w[0:4] = np.array([5, 1.2, -3.4, 5.6])

features = np.random.normal(size=(n_train + n_test, 1))
np.random.shuffle(features)
poly_features = np.power(features, np.arange(max_degree).reshape(1, -1))
for i in range(max_degree):
    poly_features[:, i] /= math.gamma(i + 1)  # `gamma(n)` = (n-1)!
# Shape of `labels`: (`n_train` + `n_test`,)
labels = np.dot(poly_features, true_w)
labels += np.random.normal(scale=0.1, size=labels.shape)

# %% [markdown]
# Again, monomials stored in `poly_features`
# are rescaled by the gamma function,
# where $\Gamma(n)=(n-1)!$.
# [**Take a look at the first 2 samples**] from the generated dataset.
# The value 1 is technically a feature,
# namely the constant feature corresponding to the bias.

# %%
# Convert from NumPy ndarrays to tensors
true_w, features, poly_features, labels = [
    torch.tensor(x, dtype=torch.float32)
    for x in [true_w, features, poly_features, labels]]

# %%
features[:2], poly_features[:2, :], labels[:2]
# Out:
# (tensor([[-1.2389],
#          [ 0.5180]]),
#  tensor([[ 1.0000e+00, -1.2389e+00,  7.6749e-01, -3.1696e-01,  9.8173e-02,
#           -2.4326e-02,  5.0231e-03, -8.8905e-04,  1.3768e-04, -1.8954e-05,
#            2.3482e-06, -2.6449e-07,  2.7307e-08, -2.6024e-09,  2.3030e-10,
#           -1.9022e-11,  1.4730e-12, -1.0735e-13,  7.3888e-15, -4.8180e-16],
#          [ 1.0000e+00,  5.1798e-01,  1.3415e-01,  2.3163e-02,  2.9995e-03,
#            3.1074e-04,  2.6826e-05,  1.9851e-06,  1.2853e-07,  7.3972e-09,
#            3.8316e-10,  1.8043e-11,  7.7882e-13,  3.1032e-14,  1.1481e-15,
#            3.9648e-17,  1.2836e-18,  3.9109e-20,  1.1254e-21,  3.0682e-23]]),
#  tensor([-0.9373,  5.4230]))

# %% [markdown]
# ### Training and Testing the Model
#
# Let us first [**implement a function to evaluate the loss on a given dataset**].

# %%
def evaluate_loss(net, data_iter, loss):  #@save
    """Evaluate the loss of a model on the given dataset."""
    metric = d2l.Accumulator(2)  # Sum of losses, no. of examples
    for X, y in data_iter:
        out = net(X)
        y = y.reshape(out.shape)
        l = loss(out, y)
        metric.add(l.sum(), l.numel())
    return metric[0] / metric[1]

# %% [markdown]
# Now [**define the training function**].

# %%
def train(train_features, test_features, train_labels, test_labels,
          num_epochs=400):
    loss = nn.MSELoss()
    input_shape = train_features.shape[-1]
    # Switch off the bias since we already catered for it in the polynomial
    # features
    net = nn.Sequential(nn.Linear(input_shape, 1, bias=False))
    batch_size = min(10, train_labels.shape[0])
    train_iter = d2l.load_array((train_features, train_labels.reshape(-1, 1)),
                                batch_size)
    test_iter = d2l.load_array((test_features, test_labels.reshape(-1, 1)),
                               batch_size, is_train=False)
    trainer = torch.optim.SGD(net.parameters(), lr=0.01)
    animator = d2l.Animator(xlabel='epoch', ylabel='loss', yscale='log',
                            xlim=[1, num_epochs], ylim=[1e-3, 1e2],
                            legend=['train', 'test'])
    for epoch in range(num_epochs):
        d2l.train_epoch_ch3(net, train_iter, loss, trainer)
        if epoch == 0 or (epoch + 1) % 20 == 0:
            animator.add(epoch + 1, (evaluate_loss(
                net, train_iter, loss), evaluate_loss(net, test_iter, loss)))
    print('weight:', net[0].weight.data.numpy())

# %% [markdown]
# ### [**Third-Order Polynomial Function Fitting (Normal)**]
#
# We will begin by first using a third-order polynomial function, which is the same order as that of the data generation function.
# The results show that this model's training and test losses can be both effectively reduced.
# The learned model parameters are also close
# to the true values $w = [5, 1.2, -3.4, 5.6]$.

# %%
# Pick the first four dimensions, i.e., 1, x, x^2/2!, x^3/3! from the
# polynomial features
train(poly_features[:n_train, :4], poly_features[n_train:, :4],
      labels[:n_train], labels[n_train:])
# Out:
# weight: [[ 4.985216   1.2240278 -3.3800998  5.5498247]]

# %% [markdown]
# ### [**Linear Function Fitting (Underfitting)**]
#
# Let us take another look at linear function fitting.
# After the decline in early epochs,
# it becomes difficult to further decrease
# this model's training loss.
# After the last epoch iteration has been completed,
# the training loss is still high.
# When used to fit nonlinear patterns
# (like the third-order polynomial function here)
# linear models are liable to underfit.

# %%
# Pick the first two dimensions, i.e., 1, x, from the polynomial features
train(poly_features[:n_train, :2], poly_features[n_train:, :2],
      labels[:n_train], labels[n_train:])
# Out:
# weight: [[3.3374836 3.2660062]]

# %% [markdown]
# ### [**Higher-Order Polynomial Function Fitting  (Overfitting)**]
#
# Now let us try to train the model
# using a polynomial of too high degree.
# Here, there are insufficient data to learn that
# the higher-degree coefficients should have values close to zero.
# As a result, our overly-complex model
# is so susceptible that it is being influenced
# by noise in the training data.
# Though the training loss can be effectively reduced,
# the test loss is still much higher.
# It shows that
# the complex model overfits the data.

# %%
# Pick all the dimensions from the polynomial features
train(poly_features[:n_train, :], poly_features[n_train:, :],
      labels[:n_train], labels[n_train:], num_epochs=1500)
# Out:
# weight: [[ 4.9726901e+00  1.2588897e+00 -3.2778852e+00  5.2731285e+00
#   -4.8230624e-01  1.2178495e+00  6.9669217e-02  2.6496309e-01
#    8.5530709e-03 -1.5316367e-01  1.9745621e-01 -1.6474484e-01
#    2.7057554e-03 -1.5294245e-01 -1.3626856e-01 -2.4371855e-02
#    3.8370728e-02  9.4150215e-02  2.1460949e-01  2.0848191e-01]]

# %% [markdown]
# In the subsequent sections, we will continue
# to discuss overfitting problems
# and methods for dealing with them,
# such as weight decay and dropout.
#
#
# ## Summary
#
# * Since the generalization error cannot be estimated based on the training error, simply minimizing the training error will not necessarily mean a reduction in the generalization error. Machine learning models need to be careful to safeguard against overfitting so as to minimize the generalization error.
# * A validation set can be used for model selection, provided that it is not used too liberally.
# * Underfitting means that a model is not able to reduce the training error. When training error is much lower than validation error, there is overfitting.
# * We should choose an appropriately complex model and avoid using insufficient training samples.
#
#
# ## Exercises
#
# 1. Can you solve the polynomial regression problem exactly? Hint: use linear algebra.
# 1. Consider model selection for polynomials:
#     1. Plot the training loss vs. model complexity (degree of the polynomial). What do you observe? What degree of polynomial do you need to reduce the training loss to 0?
#     1. Plot the test loss in this case.
#     1. Generate the same plot as a function of the amount of data.
# 1. What happens if you drop the normalization ($1/i!$) of the polynomial features $x^i$? Can you fix this in some other way?
# 1. Can you ever expect to see zero generalization error?

# %% [markdown]
# [Discussions](https://discuss.d2l.ai/t/97)

# %% [markdown]
# ## My exercise solutions

# %% [markdown]
# 2. Consider model selection for polynomials:
#
#    A. Plot the training loss vs. model complexity (degree of the polynomial). What do you observe? What degree of polynomial do you need to reduce the training loss to 0?
#
#    B.  Plot the test loss in this case.
#
#    C. Generate the same plot as a function of the amount of data.

# %% [markdown]
# Let's define the train function again to support this:

# %%
def train(train_features, test_features, train_labels, test_labels,
          num_epochs=400):
    loss = nn.MSELoss()
    input_shape = train_features.shape[-1]
    # Switch off the bias since we already catered for it in the polynomial
    # features
    net = nn.Sequential(nn.Linear(input_shape, 1, bias=False))
    batch_size = min(10, train_labels.shape[0])
    train_iter = d2l.load_array((train_features, train_labels.reshape(-1, 1)),
                                batch_size)
    test_iter = d2l.load_array((test_features, test_labels.reshape(-1, 1)),
                               batch_size, is_train=False)
    trainer = torch.optim.SGD(net.parameters(), lr=0.01)
    animator = d2l.Animator(xlabel='epoch', ylabel='loss', yscale='log',
                            xlim=[1, num_epochs], ylim=[1e-3, 1e2],
                            legend=['train', 'test'])
    for epoch in range(num_epochs):
        d2l.train_epoch_ch3(net, train_iter, loss, trainer)
        if epoch == 0 or (epoch + 1) % 20 == 0:
            animator.add(epoch + 1, (evaluate_loss(
                net, train_iter, loss), evaluate_loss(net, test_iter, loss)))
    print('weight:', net[0].weight.data.numpy())
    return evaluate_loss(net, train_iter, loss) # returns train loss

# %%
train_losses = []

for polynomial_degree in range(1, (max_degree + 1)): # max_degree is the maximum degree of the polynomial defined earlier
    train_loss = train(poly_features[:n_train, :polynomial_degree], poly_features[n_train:, :polynomial_degree], labels[:n_train], labels[n_train:])
    train_losses.append(train_loss)
# Out:
# weight: [[ 4.9967666e+00  1.3407426e+00 -3.4179306e+00  5.0027986e+00
#   -3.0632455e-02  1.3109347e+00  2.2555459e-01  4.0105945e-01
#   -1.4085010e-01  1.3971576e-01  2.1996969e-01 -6.1352309e-02
#   -1.6012342e-01 -1.7938085e-01 -7.6030351e-02 -1.5674438e-02
#   -1.3489433e-01  7.2109006e-02 -1.4654046e-01  1.7997338e-03]]

# %%
train_losses
# Out:
# [14.609918308258056,
#  3.7407299876213074,
#  2.4358026325702666,
#  0.011575734568759799,
#  0.013392888940870762,
#  0.016907503269612788,
#  0.014513966627418995,
#  0.018140080012381078,
#  0.016676589008420707,
#  0.017366003803908826,
#  0.01647416828200221,
#  0.015491637401282787,
#  0.015093132900074125,
#  0.015533686615526676,
#  0.01563574085012078,
#  0.015562291769310833,
#  0.01732472898438573,
#  0.015184828639030456,
#  0.015409748163074255,
#  0.01633204664103687]

# %% [markdown]
# Well, the loss is never truly 0, but a polynomial of degree 4 seems to get close to 0.

# %% [markdown]
# Let's now plot the losses for polynomial of degree 4:

# %%
train(poly_features[:n_train, :4], poly_features[n_train:, :4], labels[:n_train], labels[n_train:])
# Out:
# weight: [[ 4.985669   1.2235858 -3.380956   5.5516224]]
# 0.011584407230839134

# %% [markdown]
# OK, now let's generate the plot of the loss as the function of the amount of data:

# %% [markdown]
# First, let's check the data shape:

# %%
poly_features.shape
# Out:
# torch.Size([200, 20])

# %% [markdown]
# I'll vary the data along the first dimension (the amount of data). Let me first modify the train function:

# %%
def train(train_features, test_features, train_labels, test_labels,
          num_epochs=400):
    # I'm commenting out the animator and the print parts
    loss = nn.MSELoss()
    input_shape = train_features.shape[-1]
    # Switch off the bias since we already catered for it in the polynomial
    # features
    net = nn.Sequential(nn.Linear(input_shape, 1, bias=False))
    batch_size = min(10, train_labels.shape[0])
    train_iter = d2l.load_array((train_features, train_labels.reshape(-1, 1)),
                                batch_size)
    test_iter = d2l.load_array((test_features, test_labels.reshape(-1, 1)),
                               batch_size, is_train=False)
    trainer = torch.optim.SGD(net.parameters(), lr=0.01)
    #animator = d2l.Animator(xlabel='epoch', ylabel='loss', yscale='log',
    #                        xlim=[1, num_epochs], ylim=[1e-3, 1e2],
    #                        legend=['train', 'test'])
    for epoch in range(num_epochs):
        d2l.train_epoch_ch3(net, train_iter, loss, trainer)
        #if epoch == 0 or (epoch + 1) % 20 == 0:
        #    animator.add(epoch + 1, (evaluate_loss(
        #        net, train_iter, loss), evaluate_loss(net, test_iter, loss)))
    #print('weight:', net[0].weight.data.numpy())
    # returns train and test loss
    print("just before the return in train")
    print("train_iter")
    print(train_iter)
    print("len(train_iter)")
    print(len(train_iter)) # returns the number of batches (https://discuss.pytorch.org/t/what-is-len-dataloader-equal-to/52472)
    print("test_iter")
    print(test_iter)
    print("len(test_iter)")
    print(len(test_iter))
    return [evaluate_loss(net, train_iter, loss), evaluate_loss(net, test_iter, loss)]

# %% [markdown]
# ### Note: I added some debugging output above for debugging purposes. I fixed the bug, but I'm keeping it here.

# %% [markdown]
# And then the loss function:

# %%
def evaluate_loss(net, data_iter, loss):  #@save
    """Evaluate the loss of a model on the given dataset."""
    metric = d2l.Accumulator(2)  # Sum of losses, no. of examples
    for X, y in data_iter:
        out = net(X)
        y = y.reshape(out.shape)
        l = loss(out, y)
        metric.add(l.sum(), l.numel())
    print("metric[0]:")
    print(metric[0])
    print("metric[1]:")
    print(metric[1])
    return metric[0] / metric[1]

# %%
train_losses = []
test_losses = []

# %%
for number_of_examples in range(1, 200):
    train_loss, test_loss = train(poly_features[:number_of_examples, :3], poly_features[number_of_examples:, :3], labels[:number_of_examples], labels[number_of_examples:])
    train_losses.append(train_loss)
    test_losses.append(test_loss)
# Out:
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d60>
# len(train_iter)
# 1
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81e50>
# len(test_iter)
# 199
# metric[0]:
# 8.881784197001252e-14
# metric[1]:
# 1.0
# metric[0]:
# 7888.1277867257595
# metric[1]:
# 199.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815d00>
# len(train_iter)
# 1
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7f46c70>
# len(test_iter)
# 99
# metric[0]:
# 0.0011044297134503722
# metric[1]:
# 1.0
# metric[0]:
# 957.0960379787721
# metric[1]:
# 99.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecc8a160>
# len(train_iter)
# 1
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277b50>
# len(test_iter)
# 66
# metric[0]:
# 0.16691161692142487
# metric[1]:
# 1.0
# metric[0]:
# 756.1228746324778
# metric[1]:
# 66.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815e20>
# len(train_iter)
# 1
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81e80>
# len(test_iter)
# 49
# metric[0]:
# 0.7485787272453308
# metric[1]:
# 1.0
# metric[0]:
# 476.43038499355316
# metric[1]:
# 49.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277e50>
# len(train_iter)
# 1
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44f1937e80>
# len(test_iter)
# 39
# metric[0]:
# 0.9088751673698425
# metric[1]:
# 1.0
# metric[0]:
# 218.02048009634018
# metric[1]:
# 39.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81fa0>
# len(train_iter)
# 1
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a810a0>
# len(test_iter)
# 33
# metric[0]:
# 0.8236191868782043
# metric[1]:
# 1.0
# metric[0]:
# 196.96653166413307
# metric[1]:
# 33.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277310>
# len(train_iter)
# 1
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecc2f490>
# len(test_iter)
# 28
# metric[0]:
# 0.7971262335777283
# metric[1]:
# 1.0
# metric[0]:
# 161.86624085903168
# metric[1]:
# 28.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a819a0>
# len(train_iter)
# 1
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e370>
# len(test_iter)
# 24
# metric[0]:
# 0.6533433794975281
# metric[1]:
# 1.0
# metric[0]:
# 141.20344361662865
# metric[1]:
# 24.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec2772e0>
# len(train_iter)
# 1
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca7c460>
# len(test_iter)
# 22
# metric[0]:
# 0.9649059772491455
# metric[1]:
# 1.0
# metric[0]:
# 138.07014641165733
# metric[1]:
# 22.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81e80>
# len(train_iter)
# 1
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81fa0>
# len(test_iter)
# 19
# metric[0]:
# 0.9105226397514343
# metric[1]:
# 1.0
# metric[0]:
# 121.76027423143387
# metric[1]:
# 19.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277b50>
# len(train_iter)
# 2
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec3a33d0>
# len(test_iter)
# 19
# metric[0]:
# 0.7276611030101776
# metric[1]:
# 2.0
# metric[0]:
# 128.88129833340645
# metric[1]:
# 19.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81e50>
# len(train_iter)
# 2
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca7c460>
# len(test_iter)
# 19
# metric[0]:
# 0.5689499825239182
# metric[1]:
# 2.0
# metric[0]:
# 128.9018476307392
# metric[1]:
# 19.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277e50>
# len(train_iter)
# 2
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7f46c70>
# len(test_iter)
# 19
# metric[0]:
# 1.3829986453056335
# metric[1]:
# 2.0
# metric[0]:
# 131.9714413881302
# metric[1]:
# 19.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b20>
# len(train_iter)
# 2
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecc8a160>
# len(test_iter)
# 19
# metric[0]:
# 0.7671578228473663
# metric[1]:
# 2.0
# metric[0]:
# 136.50625659525394
# metric[1]:
# 19.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277be0>
# len(train_iter)
# 2
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec83dfd0>
# len(test_iter)
# 19
# metric[0]:
# 0.7985616326332092
# metric[1]:
# 2.0
# metric[0]:
# 138.03664952516556
# metric[1]:
# 19.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b80>
# len(train_iter)
# 2
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81880>
# len(test_iter)
# 19
# metric[0]:
# 1.2911813259124756
# metric[1]:
# 2.0
# metric[0]:
# 116.02236041426659
# metric[1]:
# 19.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234100>
# len(train_iter)
# 2
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec3466a0>
# len(test_iter)
# 19
# metric[0]:
# 1.2484493255615234
# metric[1]:
# 2.0
# metric[0]:
# 118.6410097181797
# metric[1]:
# 19.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d60>
# len(train_iter)
# 2
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca7c460>
# len(test_iter)
# 19
# metric[0]:
# 1.1775396466255188
# metric[1]:
# 2.0
# metric[0]:
# 121.39925843477249
# metric[1]:
# 19.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234b20>
# len(train_iter)
# 2
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7bfa850>
# len(test_iter)
# 19
# metric[0]:
# 1.2125976085662842
# metric[1]:
# 2.0
# metric[0]:
# 125.3564877808094
# metric[1]:
# 19.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d00>
# len(train_iter)
# 2
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec3a33d0>
# len(test_iter)
# 18
# metric[0]:
# 1.2033478617668152
# metric[1]:
# 2.0
# metric[0]:
# 114.99651458859444
# metric[1]:
# 18.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81a00>
# len(train_iter)
# 3
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81fa0>
# len(test_iter)
# 18
# metric[0]:
# 1.861640989780426
# metric[1]:
# 3.0
# metric[0]:
# 116.369773209095
# metric[1]:
# 18.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d60>
# len(train_iter)
# 3
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecc8a160>
# len(test_iter)
# 18
# metric[0]:
# 1.8329657316207886
# metric[1]:
# 3.0
# metric[0]:
# 115.96652373671532
# metric[1]:
# 18.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81a00>
# len(train_iter)
# 3
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca03730>
# len(test_iter)
# 18
# metric[0]:
# 1.770572543144226
# metric[1]:
# 3.0
# metric[0]:
# 119.03087449073792
# metric[1]:
# 18.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277be0>
# len(train_iter)
# 3
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7bfa850>
# len(test_iter)
# 18
# metric[0]:
# 2.464150607585907
# metric[1]:
# 3.0
# metric[0]:
# 110.43223312497139
# metric[1]:
# 18.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81a00>
# len(train_iter)
# 3
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44f1937e80>
# len(test_iter)
# 18
# metric[0]:
# 2.4779321551322937
# metric[1]:
# 3.0
# metric[0]:
# 109.92317694425583
# metric[1]:
# 18.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d00>
# len(train_iter)
# 3
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec3a33d0>
# len(test_iter)
# 18
# metric[0]:
# 2.218248575925827
# metric[1]:
# 3.0
# metric[0]:
# 111.79151120781898
# metric[1]:
# 18.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a810a0>
# len(train_iter)
# 3
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81e50>
# len(test_iter)
# 18
# metric[0]:
# 2.4944984912872314
# metric[1]:
# 3.0
# metric[0]:
# 113.63129797577858
# metric[1]:
# 18.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec2772e0>
# len(train_iter)
# 3
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e72341f0>
# len(test_iter)
# 18
# metric[0]:
# 2.3338586688041687
# metric[1]:
# 3.0
# metric[0]:
# 115.52605232596397
# metric[1]:
# 18.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a819a0>
# len(train_iter)
# 3
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81e50>
# len(test_iter)
# 18
# metric[0]:
# 2.290541708469391
# metric[1]:
# 3.0
# metric[0]:
# 117.46170702576637
# metric[1]:
# 18.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234a60>
# len(train_iter)
# 3
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d00>
# len(test_iter)
# 17
# metric[0]:
# 9.007076501846313
# metric[1]:
# 3.0
# metric[0]:
# 171.9075130224228
# metric[1]:
# 17.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81a00>
# len(train_iter)
# 4
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e370>
# len(test_iter)
# 17
# metric[0]:
# 9.798285186290741
# metric[1]:
# 4.0
# metric[0]:
# 167.2298265695572
# metric[1]:
# 17.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44f1937e80>
# len(train_iter)
# 4
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca7c460>
# len(test_iter)
# 17
# metric[0]:
# 12.132811903953552
# metric[1]:
# 4.0
# metric[0]:
# 158.4488251209259
# metric[1]:
# 17.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca03730>
# len(train_iter)
# 4
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec2772e0>
# len(test_iter)
# 17
# metric[0]:
# 11.051265954971313
# metric[1]:
# 4.0
# metric[0]:
# 170.1401617527008
# metric[1]:
# 17.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277be0>
# len(train_iter)
# 4
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815a90>
# len(test_iter)
# 17
# metric[0]:
# 11.794902443885803
# metric[1]:
# 4.0
# metric[0]:
# 156.8616704940796
# metric[1]:
# 17.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd3c9a0>
# len(train_iter)
# 4
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e370>
# len(test_iter)
# 17
# metric[0]:
# 11.487416982650757
# metric[1]:
# 4.0
# metric[0]:
# 160.2654733657837
# metric[1]:
# 17.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277b50>
# len(train_iter)
# 4
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec3466a0>
# len(test_iter)
# 17
# metric[0]:
# 11.116405129432678
# metric[1]:
# 4.0
# metric[0]:
# 157.8608148097992
# metric[1]:
# 17.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d60>
# len(train_iter)
# 4
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81a00>
# len(test_iter)
# 17
# metric[0]:
# 11.441295623779297
# metric[1]:
# 4.0
# metric[0]:
# 155.49202013015747
# metric[1]:
# 17.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815d00>
# len(train_iter)
# 4
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec83dfd0>
# len(test_iter)
# 17
# metric[0]:
# 10.744383096694946
# metric[1]:
# 4.0
# metric[0]:
# 156.0596799850464
# metric[1]:
# 17.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e72341f0>
# len(train_iter)
# 4
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e370>
# len(test_iter)
# 17
# metric[0]:
# 10.842071652412415
# metric[1]:
# 4.0
# metric[0]:
# 156.9862152338028
# metric[1]:
# 17.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec3466a0>
# len(train_iter)
# 4
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81880>
# len(test_iter)
# 16
# metric[0]:
# 10.774900794029236
# metric[1]:
# 4.0
# metric[0]:
# 154.44589245319366
# metric[1]:
# 16.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234b20>
# len(train_iter)
# 5
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec83dfd0>
# len(test_iter)
# 16
# metric[0]:
# 10.82252261810936
# metric[1]:
# 5.0
# metric[0]:
# 144.6294503211975
# metric[1]:
# 16.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815100>
# len(train_iter)
# 5
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277be0>
# len(test_iter)
# 16
# metric[0]:
# 12.841859817504883
# metric[1]:
# 5.0
# metric[0]:
# 153.53090500831604
# metric[1]:
# 16.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81e50>
# len(train_iter)
# 5
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234b20>
# len(test_iter)
# 16
# metric[0]:
# 13.705676913261414
# metric[1]:
# 5.0
# metric[0]:
# 158.2687028646469
# metric[1]:
# 16.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecc8a160>
# len(train_iter)
# 5
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277b50>
# len(test_iter)
# 16
# metric[0]:
# 14.608228087425232
# metric[1]:
# 5.0
# metric[0]:
# 159.38621306419373
# metric[1]:
# 16.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecc8a160>
# len(train_iter)
# 5
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d00>
# len(test_iter)
# 16
# metric[0]:
# 11.928863644599915
# metric[1]:
# 5.0
# metric[0]:
# 160.780007481575
# metric[1]:
# 16.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d60>
# len(train_iter)
# 5
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277b50>
# len(test_iter)
# 16
# metric[0]:
# 12.186728835105896
# metric[1]:
# 5.0
# metric[0]:
# 158.35573506355286
# metric[1]:
# 16.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81e80>
# len(train_iter)
# 5
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b80>
# len(test_iter)
# 16
# metric[0]:
# 12.384335160255432
# metric[1]:
# 5.0
# metric[0]:
# 155.22464871406555
# metric[1]:
# 16.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81e80>
# len(train_iter)
# 5
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecc2f490>
# len(test_iter)
# 16
# metric[0]:
# 12.222754120826721
# metric[1]:
# 5.0
# metric[0]:
# 152.1861833333969
# metric[1]:
# 16.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815e20>
# len(train_iter)
# 5
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b20>
# len(test_iter)
# 16
# metric[0]:
# 12.754004299640656
# metric[1]:
# 5.0
# metric[0]:
# 154.18154740333557
# metric[1]:
# 16.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd3c9a0>
# len(train_iter)
# 5
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81880>
# len(test_iter)
# 15
# metric[0]:
# 12.148483037948608
# metric[1]:
# 5.0
# metric[0]:
# 154.85409772396088
# metric[1]:
# 15.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815d00>
# len(train_iter)
# 6
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81e80>
# len(test_iter)
# 15
# metric[0]:
# 13.781930565834045
# metric[1]:
# 6.0
# metric[0]:
# 146.00286400318146
# metric[1]:
# 15.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b20>
# len(train_iter)
# 6
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815100>
# len(test_iter)
# 15
# metric[0]:
# 13.15124499797821
# metric[1]:
# 6.0
# metric[0]:
# 145.26076900959015
# metric[1]:
# 15.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815e20>
# len(train_iter)
# 6
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d60>
# len(test_iter)
# 15
# metric[0]:
# 14.033571243286133
# metric[1]:
# 6.0
# metric[0]:
# 145.97640669345856
# metric[1]:
# 15.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234a60>
# len(train_iter)
# 6
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d00>
# len(test_iter)
# 15
# metric[0]:
# 13.700520247220993
# metric[1]:
# 6.0
# metric[0]:
# 148.35334885120392
# metric[1]:
# 15.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca7c460>
# len(train_iter)
# 6
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b80>
# len(test_iter)
# 15
# metric[0]:
# 14.776365041732788
# metric[1]:
# 6.0
# metric[0]:
# 152.5495320558548
# metric[1]:
# 15.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca03730>
# len(train_iter)
# 6
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7f46c70>
# len(test_iter)
# 15
# metric[0]:
# 13.69984233379364
# metric[1]:
# 6.0
# metric[0]:
# 148.39842629432678
# metric[1]:
# 15.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d60>
# len(train_iter)
# 6
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815e20>
# len(test_iter)
# 15
# metric[0]:
# 13.138933956623077
# metric[1]:
# 6.0
# metric[0]:
# 148.1072187423706
# metric[1]:
# 15.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234100>
# len(train_iter)
# 6
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81e80>
# len(test_iter)
# 15
# metric[0]:
# 13.380186915397644
# metric[1]:
# 6.0
# metric[0]:
# 149.9730155467987
# metric[1]:
# 15.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd3c9a0>
# len(train_iter)
# 6
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81e50>
# len(test_iter)
# 15
# metric[0]:
# 13.287481844425201
# metric[1]:
# 6.0
# metric[0]:
# 146.87645971775055
# metric[1]:
# 15.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec2772e0>
# len(train_iter)
# 6
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81fa0>
# len(test_iter)
# 14
# metric[0]:
# 13.480514764785767
# metric[1]:
# 6.0
# metric[0]:
# 146.34405994415283
# metric[1]:
# 14.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277310>
# len(train_iter)
# 7
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b80>
# len(test_iter)
# 14
# metric[0]:
# 14.721201121807098
# metric[1]:
# 7.0
# metric[0]:
# 156.1016490459442
# metric[1]:
# 14.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e72341f0>
# len(train_iter)
# 7
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815d00>
# len(test_iter)
# 14
# metric[0]:
# 14.794241726398468
# metric[1]:
# 7.0
# metric[0]:
# 150.57090866565704
# metric[1]:
# 14.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277dc0>
# len(train_iter)
# 7
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec3466a0>
# len(test_iter)
# 14
# metric[0]:
# 14.730754613876343
# metric[1]:
# 7.0
# metric[0]:
# 139.68514609336853
# metric[1]:
# 14.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234100>
# len(train_iter)
# 7
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815d00>
# len(test_iter)
# 14
# metric[0]:
# 14.407851576805115
# metric[1]:
# 7.0
# metric[0]:
# 144.60261154174805
# metric[1]:
# 14.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7f46c70>
# len(train_iter)
# 7
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234a60>
# len(test_iter)
# 14
# metric[0]:
# 14.786621809005737
# metric[1]:
# 7.0
# metric[0]:
# 146.43287712335587
# metric[1]:
# 14.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81a00>
# len(train_iter)
# 7
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec3466a0>
# len(test_iter)
# 14
# metric[0]:
# 14.47301834821701
# metric[1]:
# 7.0
# metric[0]:
# 143.9194815158844
# metric[1]:
# 14.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec3466a0>
# len(train_iter)
# 7
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec83dfd0>
# len(test_iter)
# 14
# metric[0]:
# 14.678890526294708
# metric[1]:
# 7.0
# metric[0]:
# 145.5923389196396
# metric[1]:
# 14.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815100>
# len(train_iter)
# 7
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b80>
# len(test_iter)
# 14
# metric[0]:
# 14.42758595943451
# metric[1]:
# 7.0
# metric[0]:
# 144.51658296585083
# metric[1]:
# 14.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd3c9a0>
# len(train_iter)
# 7
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81e80>
# len(test_iter)
# 14
# metric[0]:
# 14.613206207752228
# metric[1]:
# 7.0
# metric[0]:
# 144.90248596668243
# metric[1]:
# 14.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7bfa850>
# len(train_iter)
# 7
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a819a0>
# len(test_iter)
# 13
# metric[0]:
# 14.515752792358398
# metric[1]:
# 7.0
# metric[0]:
# 144.7434543967247
# metric[1]:
# 13.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecc8a160>
# len(train_iter)
# 8
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b80>
# len(test_iter)
# 13
# metric[0]:
# 15.013546630740166
# metric[1]:
# 8.0
# metric[0]:
# 155.7545667886734
# metric[1]:
# 13.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a810a0>
# len(train_iter)
# 8
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44f1937e80>
# len(test_iter)
# 13
# metric[0]:
# 16.846533596515656
# metric[1]:
# 8.0
# metric[0]:
# 154.88425636291504
# metric[1]:
# 13.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e370>
# len(train_iter)
# 8
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81880>
# len(test_iter)
# 13
# metric[0]:
# 15.197267889976501
# metric[1]:
# 8.0
# metric[0]:
# 141.18717527389526
# metric[1]:
# 13.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b20>
# len(train_iter)
# 8
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec83dfd0>
# len(test_iter)
# 13
# metric[0]:
# 15.448541045188904
# metric[1]:
# 8.0
# metric[0]:
# 145.0848081111908
# metric[1]:
# 13.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7bfa850>
# len(train_iter)
# 8
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b80>
# len(test_iter)
# 13
# metric[0]:
# 15.49196171760559
# metric[1]:
# 8.0
# metric[0]:
# 141.97982770204544
# metric[1]:
# 13.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecc2f490>
# len(train_iter)
# 8
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d00>
# len(test_iter)
# 13
# metric[0]:
# 15.593530774116516
# metric[1]:
# 8.0
# metric[0]:
# 142.6706292629242
# metric[1]:
# 13.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815100>
# len(train_iter)
# 8
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d00>
# len(test_iter)
# 13
# metric[0]:
# 15.46689173579216
# metric[1]:
# 8.0
# metric[0]:
# 145.2779489159584
# metric[1]:
# 13.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277b50>
# len(train_iter)
# 8
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7f46c70>
# len(test_iter)
# 13
# metric[0]:
# 15.620330154895782
# metric[1]:
# 8.0
# metric[0]:
# 144.51617169380188
# metric[1]:
# 13.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7f46c70>
# len(train_iter)
# 8
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815a90>
# len(test_iter)
# 13
# metric[0]:
# 15.573541402816772
# metric[1]:
# 8.0
# metric[0]:
# 144.22558256983757
# metric[1]:
# 13.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d00>
# len(train_iter)
# 8
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b20>
# len(test_iter)
# 12
# metric[0]:
# 15.616786181926727
# metric[1]:
# 8.0
# metric[0]:
# 144.50985026359558
# metric[1]:
# 12.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234a60>
# len(train_iter)
# 9
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815e20>
# len(test_iter)
# 12
# metric[0]:
# 20.027393266558647
# metric[1]:
# 9.0
# metric[0]:
# 111.63227725028992
# metric[1]:
# 12.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277310>
# len(train_iter)
# 9
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecc8a160>
# len(test_iter)
# 12
# metric[0]:
# 20.425812780857086
# metric[1]:
# 9.0
# metric[0]:
# 119.48618513345718
# metric[1]:
# 12.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b80>
# len(train_iter)
# 9
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca03730>
# len(test_iter)
# 12
# metric[0]:
# 21.310008883476257
# metric[1]:
# 9.0
# metric[0]:
# 109.05909621715546
# metric[1]:
# 12.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815a90>
# len(train_iter)
# 9
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277e50>
# len(test_iter)
# 12
# metric[0]:
# 20.53766441345215
# metric[1]:
# 9.0
# metric[0]:
# 111.29986810684204
# metric[1]:
# 12.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81880>
# len(train_iter)
# 9
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd3c9a0>
# len(test_iter)
# 12
# metric[0]:
# 21.191210865974426
# metric[1]:
# 9.0
# metric[0]:
# 114.50176393985748
# metric[1]:
# 12.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815a90>
# len(train_iter)
# 9
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecc8a160>
# len(test_iter)
# 12
# metric[0]:
# 20.99367243051529
# metric[1]:
# 9.0
# metric[0]:
# 112.70033586025238
# metric[1]:
# 12.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca03730>
# len(train_iter)
# 9
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecc2f490>
# len(test_iter)
# 12
# metric[0]:
# 23.685846209526062
# metric[1]:
# 9.0
# metric[0]:
# 113.73074221611023
# metric[1]:
# 12.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81e80>
# len(train_iter)
# 9
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca03730>
# len(test_iter)
# 12
# metric[0]:
# 22.007635354995728
# metric[1]:
# 9.0
# metric[0]:
# 107.66332602500916
# metric[1]:
# 12.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234100>
# len(train_iter)
# 9
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b80>
# len(test_iter)
# 12
# metric[0]:
# 21.16893643140793
# metric[1]:
# 9.0
# metric[0]:
# 106.7036046795547
# metric[1]:
# 12.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815100>
# len(train_iter)
# 9
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277be0>
# len(test_iter)
# 11
# metric[0]:
# 21.067826449871063
# metric[1]:
# 9.0
# metric[0]:
# 106.86616611480713
# metric[1]:
# 11.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecc8a160>
# len(train_iter)
# 10
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b20>
# len(test_iter)
# 11
# metric[0]:
# 23.931338012218475
# metric[1]:
# 10.0
# metric[0]:
# 116.66417092084885
# metric[1]:
# 11.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234100>
# len(train_iter)
# 10
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b20>
# len(test_iter)
# 11
# metric[0]:
# 22.347944140434265
# metric[1]:
# 10.0
# metric[0]:
# 105.05203294754028
# metric[1]:
# 11.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815d00>
# len(train_iter)
# 10
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a810a0>
# len(test_iter)
# 11
# metric[0]:
# 22.504888117313385
# metric[1]:
# 10.0
# metric[0]:
# 109.73458087444305
# metric[1]:
# 11.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234b20>
# len(train_iter)
# 10
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815a90>
# len(test_iter)
# 11
# metric[0]:
# 22.129980742931366
# metric[1]:
# 10.0
# metric[0]:
# 107.51724517345428
# metric[1]:
# 11.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815e20>
# len(train_iter)
# 10
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca7c460>
# len(test_iter)
# 11
# metric[0]:
# 29.58205223083496
# metric[1]:
# 10.0
# metric[0]:
# 106.10562801361084
# metric[1]:
# 11.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234100>
# len(train_iter)
# 10
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e370>
# len(test_iter)
# 11
# metric[0]:
# 24.46934413909912
# metric[1]:
# 10.0
# metric[0]:
# 93.34225237369537
# metric[1]:
# 11.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277dc0>
# len(train_iter)
# 10
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815e20>
# len(test_iter)
# 11
# metric[0]:
# 27.899429380893707
# metric[1]:
# 10.0
# metric[0]:
# 93.51647353172302
# metric[1]:
# 11.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e370>
# len(train_iter)
# 10
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277b50>
# len(test_iter)
# 11
# metric[0]:
# 24.59728741645813
# metric[1]:
# 10.0
# metric[0]:
# 90.95413917303085
# metric[1]:
# 11.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e72341f0>
# len(train_iter)
# 10
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277be0>
# len(test_iter)
# 11
# metric[0]:
# 24.46934485435486
# metric[1]:
# 10.0
# metric[0]:
# 91.9656497274409
# metric[1]:
# 11.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277be0>
# len(train_iter)
# 10
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca03730>
# len(test_iter)
# 10
# metric[0]:
# 24.35910803079605
# metric[1]:
# 10.0
# metric[0]:
# 91.64920580387115
# metric[1]:
# 10.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecc2f490>
# len(train_iter)
# 11
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca7c460>
# len(test_iter)
# 10
# metric[0]:
# 25.062337636947632
# metric[1]:
# 11.0
# metric[0]:
# 90.3053680062294
# metric[1]:
# 10.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e370>
# len(train_iter)
# 11
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277dc0>
# len(test_iter)
# 10
# metric[0]:
# 25.14676934480667
# metric[1]:
# 11.0
# metric[0]:
# 93.74274808168411
# metric[1]:
# 10.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277be0>
# len(train_iter)
# 11
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec83dfd0>
# len(test_iter)
# 10
# metric[0]:
# 25.831262797117233
# metric[1]:
# 11.0
# metric[0]:
# 91.31674605607986
# metric[1]:
# 10.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7f46c70>
# len(train_iter)
# 11
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec2772e0>
# len(test_iter)
# 10
# metric[0]:
# 53.46026039123535
# metric[1]:
# 11.0
# metric[0]:
# 37.75160127878189
# metric[1]:
# 10.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d60>
# len(train_iter)
# 11
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e640>
# len(test_iter)
# 10
# metric[0]:
# 53.79828202724457
# metric[1]:
# 11.0
# metric[0]:
# 37.817077338695526
# metric[1]:
# 10.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234100>
# len(train_iter)
# 11
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7bfa850>
# len(test_iter)
# 10
# metric[0]:
# 53.420117259025574
# metric[1]:
# 11.0
# metric[0]:
# 37.770094215869904
# metric[1]:
# 10.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7f46c70>
# len(train_iter)
# 11
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81880>
# len(test_iter)
# 10
# metric[0]:
# 53.58593499660492
# metric[1]:
# 11.0
# metric[0]:
# 38.15196532011032
# metric[1]:
# 10.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234a60>
# len(train_iter)
# 11
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815d00>
# len(test_iter)
# 10
# metric[0]:
# 53.71026623249054
# metric[1]:
# 11.0
# metric[0]:
# 38.19274193048477
# metric[1]:
# 10.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e640>
# len(train_iter)
# 11
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b80>
# len(test_iter)
# 10
# metric[0]:
# 53.540133118629456
# metric[1]:
# 11.0
# metric[0]:
# 37.3385306596756
# metric[1]:
# 10.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e370>
# len(train_iter)
# 11
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44f1937e80>
# len(test_iter)
# 9
# metric[0]:
# 53.59891700744629
# metric[1]:
# 11.0
# metric[0]:
# 36.25536811351776
# metric[1]:
# 9.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234100>
# len(train_iter)
# 12
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277be0>
# len(test_iter)
# 9
# metric[0]:
# 56.594619274139404
# metric[1]:
# 12.0
# metric[0]:
# 35.97125166654587
# metric[1]:
# 9.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec3466a0>
# len(train_iter)
# 12
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277be0>
# len(test_iter)
# 9
# metric[0]:
# 55.384634375572205
# metric[1]:
# 12.0
# metric[0]:
# 36.36671954393387
# metric[1]:
# 9.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e640>
# len(train_iter)
# 12
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277b50>
# len(test_iter)
# 9
# metric[0]:
# 55.51289367675781
# metric[1]:
# 12.0
# metric[0]:
# 36.462769985198975
# metric[1]:
# 9.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e72341f0>
# len(train_iter)
# 12
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277dc0>
# len(test_iter)
# 9
# metric[0]:
# 59.66736578941345
# metric[1]:
# 12.0
# metric[0]:
# 32.610376060009
# metric[1]:
# 9.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277dc0>
# len(train_iter)
# 12
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e72341f0>
# len(test_iter)
# 9
# metric[0]:
# 59.09763014316559
# metric[1]:
# 12.0
# metric[0]:
# 32.91872018575668
# metric[1]:
# 9.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec3a33d0>
# len(train_iter)
# 12
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d60>
# len(test_iter)
# 9
# metric[0]:
# 58.626463651657104
# metric[1]:
# 12.0
# metric[0]:
# 33.088603258132935
# metric[1]:
# 9.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecc8a160>
# len(train_iter)
# 12
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277e50>
# len(test_iter)
# 9
# metric[0]:
# 65.63828420639038
# metric[1]:
# 12.0
# metric[0]:
# 32.494955241680145
# metric[1]:
# 9.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234a60>
# len(train_iter)
# 12
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca7c460>
# len(test_iter)
# 9
# metric[0]:
# 59.21383535861969
# metric[1]:
# 12.0
# metric[0]:
# 32.38670939207077
# metric[1]:
# 9.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec3a33d0>
# len(train_iter)
# 12
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e370>
# len(test_iter)
# 9
# metric[0]:
# 59.14841043949127
# metric[1]:
# 12.0
# metric[0]:
# 30.961342871189117
# metric[1]:
# 9.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81e80>
# len(train_iter)
# 12
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecc2f490>
# len(test_iter)
# 8
# metric[0]:
# 59.254783391952515
# metric[1]:
# 12.0
# metric[0]:
# 30.398438334465027
# metric[1]:
# 8.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234a60>
# len(train_iter)
# 13
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca03730>
# len(test_iter)
# 8
# metric[0]:
# 61.605613112449646
# metric[1]:
# 13.0
# metric[0]:
# 30.653901278972626
# metric[1]:
# 8.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec83dfd0>
# len(train_iter)
# 13
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234100>
# len(test_iter)
# 8
# metric[0]:
# 60.024798929691315
# metric[1]:
# 13.0
# metric[0]:
# 30.556183397769928
# metric[1]:
# 8.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234b20>
# len(train_iter)
# 13
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e640>
# len(test_iter)
# 8
# metric[0]:
# 61.673890471458435
# metric[1]:
# 13.0
# metric[0]:
# 29.949854016304016
# metric[1]:
# 8.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd3c9a0>
# len(train_iter)
# 13
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234b20>
# len(test_iter)
# 8
# metric[0]:
# 61.088924407958984
# metric[1]:
# 13.0
# metric[0]:
# 30.549902737140656
# metric[1]:
# 8.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234b20>
# len(train_iter)
# 13
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815e20>
# len(test_iter)
# 8
# metric[0]:
# 60.96795392036438
# metric[1]:
# 13.0
# metric[0]:
# 30.730406284332275
# metric[1]:
# 8.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d60>
# len(train_iter)
# 13
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277dc0>
# len(test_iter)
# 8
# metric[0]:
# 70.37593907117844
# metric[1]:
# 13.0
# metric[0]:
# 30.81410664319992
# metric[1]:
# 8.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e72341f0>
# len(train_iter)
# 13
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81880>
# len(test_iter)
# 8
# metric[0]:
# 69.72471499443054
# metric[1]:
# 13.0
# metric[0]:
# 30.881287693977356
# metric[1]:
# 8.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d00>
# len(train_iter)
# 13
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7f46c70>
# len(test_iter)
# 8
# metric[0]:
# 61.105446457862854
# metric[1]:
# 13.0
# metric[0]:
# 30.483221292495728
# metric[1]:
# 8.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234b20>
# len(train_iter)
# 13
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7bfa850>
# len(test_iter)
# 8
# metric[0]:
# 60.85695803165436
# metric[1]:
# 13.0
# metric[0]:
# 29.43939483165741
# metric[1]:
# 8.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e640>
# len(train_iter)
# 13
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277b50>
# len(test_iter)
# 7
# metric[0]:
# 60.64130413532257
# metric[1]:
# 13.0
# metric[0]:
# 29.018341898918152
# metric[1]:
# 7.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815100>
# len(train_iter)
# 14
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d00>
# len(test_iter)
# 7
# metric[0]:
# 63.388312220573425
# metric[1]:
# 14.0
# metric[0]:
# 29.30415505170822
# metric[1]:
# 7.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e640>
# len(train_iter)
# 14
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a819a0>
# len(test_iter)
# 7
# metric[0]:
# 61.704482436180115
# metric[1]:
# 14.0
# metric[0]:
# 29.47926962375641
# metric[1]:
# 7.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815d00>
# len(train_iter)
# 14
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277dc0>
# len(test_iter)
# 7
# metric[0]:
# 62.025511503219604
# metric[1]:
# 14.0
# metric[0]:
# 29.30562686920166
# metric[1]:
# 7.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca03730>
# len(train_iter)
# 14
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234b20>
# len(test_iter)
# 7
# metric[0]:
# 62.28544223308563
# metric[1]:
# 14.0
# metric[0]:
# 29.318542897701263
# metric[1]:
# 7.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815e20>
# len(train_iter)
# 14
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecc2f490>
# len(test_iter)
# 7
# metric[0]:
# 62.535478353500366
# metric[1]:
# 14.0
# metric[0]:
# 29.311391234397888
# metric[1]:
# 7.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81e50>
# len(train_iter)
# 14
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277b50>
# len(test_iter)
# 7
# metric[0]:
# 61.955103516578674
# metric[1]:
# 14.0
# metric[0]:
# 29.560644268989563
# metric[1]:
# 7.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec3a33d0>
# len(train_iter)
# 14
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815a90>
# len(test_iter)
# 7
# metric[0]:
# 61.925453305244446
# metric[1]:
# 14.0
# metric[0]:
# 29.641132056713104
# metric[1]:
# 7.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277be0>
# len(train_iter)
# 14
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234100>
# len(test_iter)
# 7
# metric[0]:
# 61.82788634300232
# metric[1]:
# 14.0
# metric[0]:
# 29.560643076896667
# metric[1]:
# 7.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd3c9a0>
# len(train_iter)
# 14
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e640>
# len(test_iter)
# 7
# metric[0]:
# 63.36699843406677
# metric[1]:
# 14.0
# metric[0]:
# 29.296343207359314
# metric[1]:
# 7.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e640>
# len(train_iter)
# 14
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a819a0>
# len(test_iter)
# 6
# metric[0]:
# 61.56761676073074
# metric[1]:
# 14.0
# metric[0]:
# 28.086796641349792
# metric[1]:
# 6.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815e20>
# len(train_iter)
# 15
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b80>
# len(test_iter)
# 6
# metric[0]:
# 91.01030683517456
# metric[1]:
# 15.0
# metric[0]:
# 37.14932155609131
# metric[1]:
# 6.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e640>
# len(train_iter)
# 15
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a810a0>
# len(test_iter)
# 6
# metric[0]:
# 64.18905431032181
# metric[1]:
# 15.0
# metric[0]:
# 28.659672260284424
# metric[1]:
# 6.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815e20>
# len(train_iter)
# 15
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b20>
# len(test_iter)
# 6
# metric[0]:
# 64.10048115253448
# metric[1]:
# 15.0
# metric[0]:
# 28.8266921043396
# metric[1]:
# 6.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e72341f0>
# len(train_iter)
# 15
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81880>
# len(test_iter)
# 6
# metric[0]:
# 63.003127694129944
# metric[1]:
# 15.0
# metric[0]:
# 28.783797025680542
# metric[1]:
# 6.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec3a33d0>
# len(train_iter)
# 15
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a810a0>
# len(test_iter)
# 6
# metric[0]:
# 66.18340140581131
# metric[1]:
# 15.0
# metric[0]:
# 29.007381081581116
# metric[1]:
# 6.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a819a0>
# len(train_iter)
# 15
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815100>
# len(test_iter)
# 6
# metric[0]:
# 62.72904986143112
# metric[1]:
# 15.0
# metric[0]:
# 28.483226776123047
# metric[1]:
# 6.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec83dfd0>
# len(train_iter)
# 15
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd3c9a0>
# len(test_iter)
# 6
# metric[0]:
# 62.62609362602234
# metric[1]:
# 15.0
# metric[0]:
# 29.134849429130554
# metric[1]:
# 6.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815a90>
# len(train_iter)
# 15
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234100>
# len(test_iter)
# 6
# metric[0]:
# 62.50176775455475
# metric[1]:
# 15.0
# metric[0]:
# 29.011867880821228
# metric[1]:
# 6.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81e50>
# len(train_iter)
# 15
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e370>
# len(test_iter)
# 6
# metric[0]:
# 64.33826959133148
# metric[1]:
# 15.0
# metric[0]:
# 25.983785271644592
# metric[1]:
# 6.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234b20>
# len(train_iter)
# 15
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b20>
# len(test_iter)
# 5
# metric[0]:
# 64.20023286342621
# metric[1]:
# 15.0
# metric[0]:
# 25.272302508354187
# metric[1]:
# 5.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b80>
# len(train_iter)
# 16
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e640>
# len(test_iter)
# 5
# metric[0]:
# 73.03036630153656
# metric[1]:
# 16.0
# metric[0]:
# 26.17328190803528
# metric[1]:
# 5.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234a60>
# len(train_iter)
# 16
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a810a0>
# len(test_iter)
# 5
# metric[0]:
# 65.56594920158386
# metric[1]:
# 16.0
# metric[0]:
# 25.67336094379425
# metric[1]:
# 5.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a819a0>
# len(train_iter)
# 16
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec3a33d0>
# len(test_iter)
# 5
# metric[0]:
# 69.89601862430573
# metric[1]:
# 16.0
# metric[0]:
# 25.25300681591034
# metric[1]:
# 5.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd3c9a0>
# len(train_iter)
# 16
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a819a0>
# len(test_iter)
# 5
# metric[0]:
# 94.91076201200485
# metric[1]:
# 16.0
# metric[0]:
# 25.42214000225067
# metric[1]:
# 5.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a819a0>
# len(train_iter)
# 16
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e640>
# len(test_iter)
# 5
# metric[0]:
# 66.18498015403748
# metric[1]:
# 16.0
# metric[0]:
# 25.379443645477295
# metric[1]:
# 5.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234a60>
# len(train_iter)
# 16
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e640>
# len(test_iter)
# 5
# metric[0]:
# 65.70342302322388
# metric[1]:
# 16.0
# metric[0]:
# 25.809706807136536
# metric[1]:
# 5.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b80>
# len(train_iter)
# 16
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d00>
# len(test_iter)
# 5
# metric[0]:
# 65.53284668922424
# metric[1]:
# 16.0
# metric[0]:
# 25.96343159675598
# metric[1]:
# 5.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e72341f0>
# len(train_iter)
# 16
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815a90>
# len(test_iter)
# 5
# metric[0]:
# 65.42001688480377
# metric[1]:
# 16.0
# metric[0]:
# 26.107970237731934
# metric[1]:
# 5.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815d00>
# len(train_iter)
# 16
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234b20>
# len(test_iter)
# 5
# metric[0]:
# 65.66705971956253
# metric[1]:
# 16.0
# metric[0]:
# 25.10895073413849
# metric[1]:
# 5.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81880>
# len(train_iter)
# 16
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81a00>
# len(test_iter)
# 4
# metric[0]:
# 65.60195344686508
# metric[1]:
# 16.0
# metric[0]:
# 24.28994631767273
# metric[1]:
# 4.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815a90>
# len(train_iter)
# 17
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277b50>
# len(test_iter)
# 4
# metric[0]:
# 68.62956213951111
# metric[1]:
# 17.0
# metric[0]:
# 24.415409088134766
# metric[1]:
# 4.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81880>
# len(train_iter)
# 17
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234100>
# len(test_iter)
# 4
# metric[0]:
# 73.41986644268036
# metric[1]:
# 17.0
# metric[0]:
# 23.8386173248291
# metric[1]:
# 4.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e72341f0>
# len(train_iter)
# 17
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec7f7130>
# len(test_iter)
# 4
# metric[0]:
# 67.22118306159973
# metric[1]:
# 17.0
# metric[0]:
# 24.356465101242065
# metric[1]:
# 4.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277dc0>
# len(train_iter)
# 17
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7f46c70>
# len(test_iter)
# 4
# metric[0]:
# 67.48270493745804
# metric[1]:
# 17.0
# metric[0]:
# 24.268615245819092
# metric[1]:
# 4.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e640>
# len(train_iter)
# 17
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277b50>
# len(test_iter)
# 4
# metric[0]:
# 67.34609723091125
# metric[1]:
# 17.0
# metric[0]:
# 24.394859075546265
# metric[1]:
# 4.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277be0>
# len(train_iter)
# 17
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e370>
# len(test_iter)
# 4
# metric[0]:
# 67.45469903945923
# metric[1]:
# 17.0
# metric[0]:
# 24.521631836891174
# metric[1]:
# 4.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44f1937e80>
# len(train_iter)
# 17
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277dc0>
# len(test_iter)
# 4
# metric[0]:
# 67.96719652414322
# metric[1]:
# 17.0
# metric[0]:
# 24.129879117012024
# metric[1]:
# 4.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d60>
# len(train_iter)
# 17
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e72341f0>
# len(test_iter)
# 4
# metric[0]:
# 68.03303629159927
# metric[1]:
# 17.0
# metric[0]:
# 23.54457414150238
# metric[1]:
# 4.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81880>
# len(train_iter)
# 17
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a819a0>
# len(test_iter)
# 4
# metric[0]:
# 67.8851637840271
# metric[1]:
# 17.0
# metric[0]:
# 22.964597463607788
# metric[1]:
# 4.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277be0>
# len(train_iter)
# 17
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234b20>
# len(test_iter)
# 3
# metric[0]:
# 68.0629752278328
# metric[1]:
# 17.0
# metric[0]:
# 21.760877013206482
# metric[1]:
# 3.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b80>
# len(train_iter)
# 18
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec3466a0>
# len(test_iter)
# 3
# metric[0]:
# 68.82179576158524
# metric[1]:
# 18.0
# metric[0]:
# 21.403779983520508
# metric[1]:
# 3.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234100>
# len(train_iter)
# 18
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca7c460>
# len(test_iter)
# 3
# metric[0]:
# 70.21542096138
# metric[1]:
# 18.0
# metric[0]:
# 21.4929940700531
# metric[1]:
# 3.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815d00>
# len(train_iter)
# 18
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234a60>
# len(test_iter)
# 3
# metric[0]:
# 69.70711940526962
# metric[1]:
# 18.0
# metric[0]:
# 21.91475737094879
# metric[1]:
# 3.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7bfa850>
# len(train_iter)
# 18
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e640>
# len(test_iter)
# 3
# metric[0]:
# 69.91029351949692
# metric[1]:
# 18.0
# metric[0]:
# 21.971402168273926
# metric[1]:
# 3.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec2772e0>
# len(train_iter)
# 18
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b80>
# len(test_iter)
# 3
# metric[0]:
# 69.57594656944275
# metric[1]:
# 18.0
# metric[0]:
# 22.293257653713226
# metric[1]:
# 3.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815a90>
# len(train_iter)
# 18
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44f1937e80>
# len(test_iter)
# 3
# metric[0]:
# 72.33127707242966
# metric[1]:
# 18.0
# metric[0]:
# 21.85750436782837
# metric[1]:
# 3.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca7c460>
# len(train_iter)
# 18
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d00>
# len(test_iter)
# 3
# metric[0]:
# 78.02443552017212
# metric[1]:
# 18.0
# metric[0]:
# 16.735796689987183
# metric[1]:
# 3.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815100>
# len(train_iter)
# 18
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca03730>
# len(test_iter)
# 3
# metric[0]:
# 76.10264122486115
# metric[1]:
# 18.0
# metric[0]:
# 16.466356992721558
# metric[1]:
# 3.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44f1937e80>
# len(train_iter)
# 18
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d60>
# len(test_iter)
# 3
# metric[0]:
# 76.27380990982056
# metric[1]:
# 18.0
# metric[0]:
# 15.96920359134674
# metric[1]:
# 3.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e370>
# len(train_iter)
# 18
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277b50>
# len(test_iter)
# 2
# metric[0]:
# 76.22568047046661
# metric[1]:
# 18.0
# metric[0]:
# 14.41856062412262
# metric[1]:
# 2.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815d00>
# len(train_iter)
# 19
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca03730>
# len(test_iter)
# 2
# metric[0]:
# 76.6121495962143
# metric[1]:
# 19.0
# metric[0]:
# 13.940688610076904
# metric[1]:
# 2.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234b20>
# len(train_iter)
# 19
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277be0>
# len(test_iter)
# 2
# metric[0]:
# 77.34816682338715
# metric[1]:
# 19.0
# metric[0]:
# 14.257192254066467
# metric[1]:
# 2.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44f1937e80>
# len(train_iter)
# 19
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca7c460>
# len(test_iter)
# 2
# metric[0]:
# 77.50381445884705
# metric[1]:
# 19.0
# metric[0]:
# 15.224003791809082
# metric[1]:
# 2.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815d00>
# len(train_iter)
# 19
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e370>
# len(test_iter)
# 2
# metric[0]:
# 77.46156656742096
# metric[1]:
# 19.0
# metric[0]:
# 14.536374688148499
# metric[1]:
# 2.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277b50>
# len(train_iter)
# 19
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44eca03730>
# len(test_iter)
# 2
# metric[0]:
# 87.47415220737457
# metric[1]:
# 19.0
# metric[0]:
# 3.5154922008514404
# metric[1]:
# 2.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec815d00>
# len(train_iter)
# 19
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277be0>
# len(test_iter)
# 2
# metric[0]:
# 87.80489408969879
# metric[1]:
# 19.0
# metric[0]:
# 3.5057194232940674
# metric[1]:
# 2.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e640>
# len(train_iter)
# 19
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d60>
# len(test_iter)
# 2
# metric[0]:
# 87.5467192530632
# metric[1]:
# 19.0
# metric[0]:
# 3.9557148218154907
# metric[1]:
# 2.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec83dfd0>
# len(train_iter)
# 19
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277dc0>
# len(test_iter)
# 2
# metric[0]:
# 89.81771349906921
# metric[1]:
# 19.0
# metric[0]:
# 3.6641212701797485
# metric[1]:
# 2.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec83dfd0>
# len(train_iter)
# 19
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d00>
# len(test_iter)
# 2
# metric[0]:
# 87.67078566551208
# metric[1]:
# 19.0
# metric[0]:
# 2.535335510969162
# metric[1]:
# 2.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234b20>
# len(train_iter)
# 19
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277310>
# len(test_iter)
# 1
# metric[0]:
# 87.69124853610992
# metric[1]:
# 19.0
# metric[0]:
# 1.9108911752700806
# metric[1]:
# 1.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277be0>
# len(train_iter)
# 20
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecc2f490>
# len(test_iter)
# 1
# metric[0]:
# 87.87862101197243
# metric[1]:
# 20.0
# metric[0]:
# 2.0304670333862305
# metric[1]:
# 1.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234a60>
# len(train_iter)
# 20
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d00>
# len(test_iter)
# 1
# metric[0]:
# 88.0345766544342
# metric[1]:
# 20.0
# metric[0]:
# 1.8913161754608154
# metric[1]:
# 1.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e640>
# len(train_iter)
# 20
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277dc0>
# len(test_iter)
# 1
# metric[0]:
# 89.61570870876312
# metric[1]:
# 20.0
# metric[0]:
# 1.7855459451675415
# metric[1]:
# 1.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecc8a160>
# len(train_iter)
# 20
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277d00>
# len(test_iter)
# 1
# metric[0]:
# 88.8746554851532
# metric[1]:
# 20.0
# metric[0]:
# 2.1295673847198486
# metric[1]:
# 1.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81b20>
# len(train_iter)
# 20
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81a00>
# len(test_iter)
# 1
# metric[0]:
# 89.47547233104706
# metric[1]:
# 20.0
# metric[0]:
# 2.258690595626831
# metric[1]:
# 1.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e370>
# len(train_iter)
# 20
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a810a0>
# len(test_iter)
# 1
# metric[0]:
# 90.797189950943
# metric[1]:
# 20.0
# metric[0]:
# 2.099867343902588
# metric[1]:
# 1.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7234a60>
# len(train_iter)
# 20
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7a81e50>
# len(test_iter)
# 1
# metric[0]:
# 97.37318813800812
# metric[1]:
# 20.0
# metric[0]:
# 2.291142702102661
# metric[1]:
# 1.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ec277be0>
# len(train_iter)
# 20
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecd0e370>
# len(test_iter)
# 1
# metric[0]:
# 89.34544825553894
# metric[1]:
# 20.0
# metric[0]:
# 1.910742163658142
# metric[1]:
# 1.0
# just before the return in train
# train_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44ecc2f490>
# len(train_iter)
# 20
# test_iter
# <torch.utils.data.dataloader.DataLoader object at 0x7f44e7f46c70>
# len(test_iter)
# 1
# metric[0]:
# 90.24108493328094
# metric[1]:
# 20.0
# metric[0]:
# 0.6721977591514587
# metric[1]:
# 1.0

# %%
train_losses = np.array(train_losses)

# %%
train_losses.shape
# Out:
# (199,)

# %%
train_losses
# Out:
# array([8.88178420e-14, 1.10442971e-03, 1.66911617e-01, 7.48578727e-01,
#        9.08875167e-01, 8.23619187e-01, 7.97126234e-01, 6.53343379e-01,
#        9.64905977e-01, 9.10522640e-01, 3.63830552e-01, 2.84474991e-01,
#        6.91499323e-01, 3.83578911e-01, 3.99280816e-01, 6.45590663e-01,
#        6.24224663e-01, 5.88769823e-01, 6.06298804e-01, 6.01673931e-01,
#        6.20546997e-01, 6.10988577e-01, 5.90190848e-01, 8.21383536e-01,
#        8.25977385e-01, 7.39416192e-01, 8.31499497e-01, 7.77952890e-01,
#        7.63513903e-01, 3.00235883e+00, 2.44957130e+00, 3.03320298e+00,
#        2.76281649e+00, 2.94872561e+00, 2.87185425e+00, 2.77910128e+00,
#        2.86032391e+00, 2.68609577e+00, 2.71051791e+00, 2.69372520e+00,
#        2.16450452e+00, 2.56837196e+00, 2.74113538e+00, 2.92164562e+00,
#        2.38577273e+00, 2.43734577e+00, 2.47686703e+00, 2.44455082e+00,
#        2.55080086e+00, 2.42969661e+00, 2.29698843e+00, 2.19187417e+00,
#        2.33892854e+00, 2.28342004e+00, 2.46272751e+00, 2.28330706e+00,
#        2.18982233e+00, 2.23003115e+00, 2.21458031e+00, 2.24675246e+00,
#        2.10302873e+00, 2.11346310e+00, 2.10439352e+00, 2.05826451e+00,
#        2.11237454e+00, 2.06757405e+00, 2.09698436e+00, 2.06108371e+00,
#        2.08760089e+00, 2.07367897e+00, 1.87669333e+00, 2.10581670e+00,
#        1.89965849e+00, 1.93106763e+00, 1.93649521e+00, 1.94919135e+00,
#        1.93336147e+00, 1.95254127e+00, 1.94669268e+00, 1.95209827e+00,
#        2.22526592e+00, 2.26953475e+00, 2.36777876e+00, 2.28196271e+00,
#        2.35457899e+00, 2.33263027e+00, 2.63176069e+00, 2.44529282e+00,
#        2.35210405e+00, 2.34086961e+00, 2.39313380e+00, 2.23479441e+00,
#        2.25048881e+00, 2.21299807e+00, 2.95820522e+00, 2.44693441e+00,
#        2.78994294e+00, 2.45972874e+00, 2.44693449e+00, 2.43591080e+00,
#        2.27839433e+00, 2.28606994e+00, 2.34829662e+00, 4.86002367e+00,
#        4.89075291e+00, 4.85637430e+00, 4.87144864e+00, 4.88275148e+00,
#        4.86728483e+00, 4.87262882e+00, 4.71621827e+00, 4.61538620e+00,
#        4.62607447e+00, 4.97228048e+00, 4.92480251e+00, 4.88553864e+00,
#        5.46985702e+00, 4.93448628e+00, 4.92903420e+00, 4.93789862e+00,
#        4.73889332e+00, 4.61729223e+00, 4.74414542e+00, 4.69914803e+00,
#        4.68984261e+00, 5.41353377e+00, 5.36343961e+00, 4.70041896e+00,
#        4.68130446e+00, 4.66471570e+00, 4.52773659e+00, 4.40746303e+00,
#        4.43039368e+00, 4.44896016e+00, 4.46681988e+00, 4.42536454e+00,
#        4.42324666e+00, 4.41627760e+00, 4.52621417e+00, 4.39768691e+00,
#        6.06735379e+00, 4.27927029e+00, 4.27336541e+00, 4.20020851e+00,
#        4.41222676e+00, 4.18193666e+00, 4.17507291e+00, 4.16678452e+00,
#        4.28921797e+00, 4.28001552e+00, 4.56439789e+00, 4.09787183e+00,
#        4.36850116e+00, 5.93192263e+00, 4.13656126e+00, 4.10646394e+00,
#        4.09580292e+00, 4.08875106e+00, 4.10419123e+00, 4.10012209e+00,
#        4.03703307e+00, 4.31881567e+00, 3.95418724e+00, 3.96957088e+00,
#        3.96153513e+00, 3.96792347e+00, 3.99807038e+00, 4.00194331e+00,
#        3.99324493e+00, 4.00370443e+00, 3.82343310e+00, 3.90085672e+00,
#        3.87261774e+00, 3.88390520e+00, 3.86533036e+00, 4.01840428e+00,
#        4.33469086e+00, 4.22792451e+00, 4.23743388e+00, 4.23476003e+00,
#        4.03221840e+00, 4.07095615e+00, 4.07914813e+00, 4.07692456e+00,
#        4.60390275e+00, 4.62131022e+00, 4.60772207e+00, 4.72724808e+00,
#        4.61425188e+00, 4.61532887e+00, 4.39393105e+00, 4.40172883e+00,
#        4.48078544e+00, 4.44373277e+00, 4.47377362e+00, 4.53985950e+00,
#        4.86865941e+00, 4.46727241e+00, 4.51205425e+00])

# %%
test_losses
# Out:
# [39.63883309912442,
#  9.667636747260325,
#  11.456407191401178,
#  9.723069081501086,
#  5.590268720418979,
#  5.9686827777010025,
#  5.780937173536846,
#  5.883476817359527,
#  6.275915745984424,
#  6.40843548586494,
#  6.783226228074024,
#  6.784307770038906,
#  6.945865336217378,
#  7.184539820802839,
#  7.265086817113977,
#  6.106440021803505,
#  6.2442636693778795,
#  6.38943465446171,
#  6.597709883200495,
#  6.388695254921913,
#  6.464987400505278,
#  6.44258465203974,
#  6.612826360596551,
#  6.13512406249841,
#  6.106843163569768,
#  6.210639511545499,
#  6.312849887543255,
#  6.41811401810911,
#  6.525650390320354,
#  10.11220664837781,
#  9.837048621738658,
#  9.320519124760347,
#  10.0082448089824,
#  9.227157087887035,
#  9.427380786222571,
#  9.285930282929364,
#  9.146589419421028,
#  9.179981175590964,
#  9.234483249047223,
#  9.652868278324604,
#  9.039340645074844,
#  9.595681563019753,
#  9.891793929040432,
#  9.961638316512108,
#  10.048750467598438,
#  9.897233441472054,
#  9.701540544629097,
#  9.511636458337307,
#  9.636346712708473,
#  10.323606514930725,
#  9.733524266878764,
#  9.68405126730601,
#  9.73176044623057,
#  9.890223256746928,
#  10.169968803723654,
#  9.893228419621785,
#  9.873814582824707,
#  9.998201036453247,
#  9.79176398118337,
#  10.45314713886806,
#  11.150117788996015,
#  10.755064904689789,
#  9.977510435240609,
#  10.328757967267718,
#  10.459491223096848,
#  10.279962965420314,
#  10.399452779974256,
#  10.322613068989344,
#  10.350177569048745,
#  11.134111876671131,
#  11.981120522205646,
#  11.91417356637808,
#  10.86055194414579,
#  11.160369854706984,
#  10.92152520784965,
#  10.974663789455708,
#  11.175226839689108,
#  11.116628591830914,
#  11.094275582295198,
#  12.042487521966299,
#  9.302689770857492,
#  9.957182094454765,
#  9.088258018096289,
#  9.274989008903503,
#  9.54181366165479,
#  9.391694655021032,
#  9.47756185134252,
#  8.971943835417429,
#  8.891967056629559,
#  9.715106010437012,
#  10.605833720077168,
#  9.550184813412754,
#  9.975870988585733,
#  9.77429501576857,
#  9.645966183055531,
#  8.48565930669958,
#  8.501497593793003,
#  8.26855810663917,
#  8.360513611585537,
#  9.164920580387115,
#  9.03053680062294,
#  9.374274808168412,
#  9.131674605607987,
#  3.775160127878189,
#  3.7817077338695526,
#  3.7770094215869903,
#  3.815196532011032,
#  3.8192741930484773,
#  3.7338530659675597,
#  4.028374234835307,
#  3.9968057407273188,
#  4.040746615992652,
#  4.05141888724433,
#  3.623375117778778,
#  3.657635576195187,
#  3.6765114731258817,
#  3.610550582408905,
#  3.598523265785641,
#  3.440149207909902,
#  3.7998047918081284,
#  3.831737659871578,
#  3.819522924721241,
#  3.743731752038002,
#  3.818737842142582,
#  3.8413007855415344,
#  3.85176333039999,
#  3.8601609617471695,
#  3.810402661561966,
#  3.679924353957176,
#  4.1454774141311646,
#  4.186307864529746,
#  4.211324231965201,
#  4.186518124171665,
#  4.18836327110018,
#  4.187341604913984,
#  4.222949181284223,
#  4.2344474366733005,
#  4.222949010985238,
#  4.185191886765616,
#  4.681132773558299,
#  6.191553592681885,
#  4.776612043380737,
#  4.8044486840566,
#  4.79729950428009,
#  4.834563513596852,
#  4.747204462687175,
#  4.855808238188426,
#  4.835311313470204,
#  4.330630878607432,
#  5.054460501670837,
#  5.2346563816070555,
#  5.1346721887588505,
#  5.050601363182068,
#  5.084428000450134,
#  5.075888729095459,
#  5.161941361427307,
#  5.192686319351196,
#  5.221594047546387,
#  5.021790146827698,
#  6.072486579418182,
#  6.103852272033691,
#  5.959654331207275,
#  6.089116275310516,
#  6.067153811454773,
#  6.098714768886566,
#  6.130407959222794,
#  6.032469779253006,
#  5.886143535375595,
#  5.741149365901947,
#  7.253625671068828,
#  7.134593327840169,
#  7.164331356684367,
#  7.304919123649597,
#  7.323800722757976,
#  7.431085884571075,
#  7.285834789276123,
#  5.5785988966623945,
#  5.4887856642405195,
#  5.323067863782247,
#  7.20928031206131,
#  6.970344305038452,
#  7.128596127033234,
#  7.612001895904541,
#  7.268187344074249,
#  1.7577461004257202,
#  1.7528597116470337,
#  1.9778574109077454,
#  1.8320606350898743,
#  1.267667755484581,
#  1.9108911752700806,
#  2.0304670333862305,
#  1.8913161754608154,
#  1.7855459451675415,
#  2.1295673847198486,
#  2.258690595626831,
#  2.099867343902588,
#  2.291142702102661,
#  1.910742163658142,
#  0.6721977591514587]

# %% [markdown]
# Now let's plot the train_losses and test_losses on the y axis and on the x axis plot the number of examples (range from 1 to 200):

# %%
import matplotlib.pyplot as plt

plt.plot(range(1, 200), train_losses)
plt.plot(range(1, 200), test_losses)

# %% [markdown]
# As the number of examples grows, the training loss increases, but the test loss falls down.

# %% [markdown]
# 3. What happens if you drop the normalization (1/𝑖!) of the polynomial features 𝑥𝑖? Can you fix this in some other way?

# %% [markdown]
# Let's see what happens if I drop the normalization (1/𝑖!) of the polynomial features 𝑥𝑖:

# %%
max_degree = 20  # Maximum degree of the polynomial
n_train, n_test = 100, 100  # Training and test dataset sizes
true_w = np.zeros(max_degree)  # Allocate lots of empty space
true_w[0:4] = np.array([5, 1.2, -3.4, 5.6])

features = np.random.normal(size=(n_train + n_test, 1))
np.random.shuffle(features)
poly_features = np.power(features, np.arange(max_degree).reshape(1, -1))
#for i in range(max_degree):
    #poly_features[:, i] /= math.gamma(i + 1)  # `gamma(n)` = (n-1)!
# Shape of `labels`: (`n_train` + `n_test`,)
labels = np.dot(poly_features, true_w)
labels += np.random.normal(scale=0.1, size=labels.shape)

# %% [markdown]
# Now let's repeat the code above:

# %%
# Convert from NumPy ndarrays to tensors
true_w, features, poly_features, labels = [
    torch.tensor(x, dtype=torch.float32)
    for x in [true_w, features, poly_features, labels]]

# %%
features[:2], poly_features[:2, :], labels[:2]
# Out:
# (tensor([[-1.5254],
#          [ 2.0987]]),
#  tensor([[ 1.0000e+00, -1.5254e+00,  2.3269e+00, -3.5494e+00,  5.4143e+00,
#           -8.2590e+00,  1.2598e+01, -1.9217e+01,  2.9314e+01, -4.4716e+01,
#            6.8210e+01, -1.0405e+02,  1.5872e+02, -2.4211e+02,  3.6931e+02,
#           -5.6335e+02,  8.5933e+02, -1.3108e+03,  1.9995e+03, -3.0501e+03],
#          [ 1.0000e+00,  2.0987e+00,  4.4047e+00,  9.2444e+00,  1.9402e+01,
#            4.0719e+01,  8.5460e+01,  1.7936e+02,  3.7643e+02,  7.9003e+02,
#            1.6581e+03,  3.4799e+03,  7.3034e+03,  1.5328e+04,  3.2170e+04,
#            6.7516e+04,  1.4170e+05,  2.9739e+05,  6.2415e+05,  1.3099e+06]]),
#  tensor([-24.6766,  44.2497]))

# %%
def evaluate_loss(net, data_iter, loss):  #@save
    """Evaluate the loss of a model on the given dataset."""
    metric = d2l.Accumulator(2)  # Sum of losses, no. of examples
    for X, y in data_iter:
        out = net(X)
        y = y.reshape(out.shape)
        l = loss(out, y)
        metric.add(l.sum(), l.numel())
    return metric[0] / metric[1]

# %%
def train(train_features, test_features, train_labels, test_labels,
          num_epochs=400):
    loss = nn.MSELoss()
    input_shape = train_features.shape[-1]
    # Switch off the bias since we already catered for it in the polynomial
    # features
    net = nn.Sequential(nn.Linear(input_shape, 1, bias=False))
    batch_size = min(10, train_labels.shape[0])
    train_iter = d2l.load_array((train_features, train_labels.reshape(-1, 1)),
                                batch_size)
    test_iter = d2l.load_array((test_features, test_labels.reshape(-1, 1)),
                               batch_size, is_train=False)
    trainer = torch.optim.SGD(net.parameters(), lr=0.01)
    animator = d2l.Animator(xlabel='epoch', ylabel='loss', yscale='log',
                            xlim=[1, num_epochs], ylim=[1e-3, 1e2],
                            legend=['train', 'test'])
    for epoch in range(num_epochs):
        d2l.train_epoch_ch3(net, train_iter, loss, trainer)
        if epoch == 0 or (epoch + 1) % 20 == 0:
            animator.add(epoch + 1, (evaluate_loss(
                net, train_iter, loss), evaluate_loss(net, test_iter, loss)))
    print('weight:', net[0].weight.data.numpy())

# %%
# Pick the first four dimensions, i.e., 1, x, x^2/2!, x^3/3! from the
# polynomial features
train(poly_features[:n_train, :4], poly_features[n_train:, :4],
      labels[:n_train], labels[n_train:])
# Out:
# weight: [[ 4.9976716  1.1969718 -3.3979168  5.6071186]]

# %% [markdown]
# ### Note: I couldn't see the below losses when I ran the function I had above, so I'm removing the y_lim from the Animator class:

# %%
def train(train_features, test_features, train_labels, test_labels,
          num_epochs=400):
    loss = nn.MSELoss()
    input_shape = train_features.shape[-1]
    # Switch off the bias since we already catered for it in the polynomial
    # features
    net = nn.Sequential(nn.Linear(input_shape, 1, bias=False))
    batch_size = min(10, train_labels.shape[0])
    train_iter = d2l.load_array((train_features, train_labels.reshape(-1, 1)),
                                batch_size)
    test_iter = d2l.load_array((test_features, test_labels.reshape(-1, 1)),
                               batch_size, is_train=False)
    trainer = torch.optim.SGD(net.parameters(), lr=0.01)
    animator = d2l.Animator(xlabel='epoch', ylabel='loss', yscale='log',
                            xlim=[1, num_epochs],
                            legend=['train', 'test'])
    for epoch in range(num_epochs):
        d2l.train_epoch_ch3(net, train_iter, loss, trainer)
        if epoch == 0 or (epoch + 1) % 20 == 0:
            animator.add(epoch + 1, (evaluate_loss(
                net, train_iter, loss), evaluate_loss(net, test_iter, loss)))
    print('weight:', net[0].weight.data.numpy())

# %%
# Pick the first two dimensions, i.e., 1, x, from the polynomial features
train(poly_features[:n_train, :2], poly_features[n_train:, :2],
      labels[:n_train], labels[n_train:])
# Out:
# weight: [[ 2.816145 19.284414]]

# %%
# Pick all the dimensions from the polynomial features
train(poly_features[:n_train, :], poly_features[n_train:, :],
      labels[:n_train], labels[n_train:], num_epochs=1500)
# Out:
# weight: [[nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan]]

# %% [markdown]
# If you drop the normalization (1/𝑖!) of the polynomial features 𝑥𝑖 then there's a much larger gap between the train and test loss when the model underfits. When the model is optimal the loss decreases more rapidly, but when the model is too expressive no loss gets plotted.
#
# The book explains why:
#
# "For optimization, we typically want to avoid very large values of gradients or losses. This is why the features are rescaled from 𝑥𝑖 to 𝑥𝑖𝑖!. It allows us to avoid very large values for large exponents 𝑖."
#
# What happens is that the loss function has a large value and the gradient probably explodes. Another way to fix this would be to clip the gradients.

# %% [markdown]
# 4. Can you ever expect to see zero generalization error?

# %% [markdown]
# No, I can't, since there's always some noise in the data and therefore classifiers can't be perfect.
